# %% [markdown]
# # Lab 4 - Combining Dataframes

# %% [markdown]
# ## NFL Offense Data

# %%
import pandas as pd
from glob import glob

# %% [markdown]
# 1. Import the NFL week 3, 4, and 5 data and add a week column to dataset and set the value to 3, 4, or 5 for all rows from that week.

# %%
stacked_files = sorted(glob('nfloffenseweek*.csv'))
stacked_files
# Out:
# ['nfloffenseweek3.csv', 'nfloffenseweek4.csv', 'nfloffenseweek5.csv']

# %%
week3 = pd.read_csv("nfloffenseweek3.csv")

# %%
week4 = pd.read_csv("nfloffenseweek4.csv")

# %%
week5 = pd.read_csv("nfloffenseweek4.csv")

# %% [markdown]
# 2. Combine the weekly dataframes by adding the dataframes together row-wise.

# %%
pd.concat((pd.read_csv(file) for file in stacked_files), ignore_index=True)
# Out:
#     rank                 team  games  points_scored  total_yards  \
# 0      1     Baltimore Ravens      3             99         1141
# 1      2        Detroit Lions      3             95         1227
# 2      3        Buffalo Bills      3             91         1324
# 3      4   Kansas City Chiefs      3             88         1122
# 4      5  Philadelphia Eagles      3             86         1341
# ..   ...                  ...    ...            ...          ...
# 91    28  San Francisco 49ers      4             71         1298
# 92    29     Los Angeles Rams      4             70         1176
# 93    30       Denver Broncos      4             66         1343
# 94    31        Chicago Bears      4             64         1099
# 95    32   Indianapolis Colts      4             57         1359
#
#     offensive_plays  yards_per_play  turnovers_lost  fumbles_lost  1st_downs  \
# 0               166             6.9               3             1         55
# 1               203             6.0               2             0         63
# 2               213             6.2               5             3         77
# 3               180             6.2               3             2         68
# 4               208             6.4               1             0         73
# ..              ...             ...             ...           ...        ...
# 91              238             5.5               5             3         68
# 92              248             4.7               9             3         79
# 93              247             5.4               4             3         66
# 94              219             5.0               7             3         59
# 95              270             5.0               9             4         82
#
#     ...  rushing_yards  rushing_touchdowns  rushing_yards_per_attempt  \
# 0   ...            406                   2                        5.6
# 1   ...            511                   5                        5.9
# 2   ...            337                   1                        4.7
# 3   ...            279                   2                        4.1
# 4   ...            451                   6                        4.4
# ..  ...            ...                 ...                        ...
# 91  ...            541                   4                        4.4
# 92  ...            274                   3                        3.3
# 93  ...            438                   2                        4.2
# 94  ...            709                   4                        5.2
# 95  ...            351                   1                        3.5
#
#     rushing_1st_downs  penalties  penalty_yards  1st_down_penalties  \
# 0                  18          8             44                   5
# 1                  20         15            129                   5
# 2                  22         20            136                   6
# 3                  15         15            124                   8
# 4                  26         23            173                   6
# ..                ...        ...            ...                 ...
# 91                 29         24            190                   8
# 92                 17         14            131                   6
# 93                 20         37            286                   7
# 94                 34         21            171                   8
# 95                 22         23            203                   5
#
#     percentage_scoring_drives  percentage_turnover_drives  expected_points
# 0                        42.9                         8.6            35.63
# 1                        40.5                         5.4            31.05
# 2                        46.7                        16.7            47.46
# 3                        45.2                         6.5            40.73
# 4                        39.4                         3.0            45.06
# ..                        ...                         ...              ...
# 91                       27.3                        11.4            -1.21
# 92                       35.9                        23.1            -8.08
# 93                       31.8                         9.1            -6.92
# 94                       31.8                        13.6            -5.87
# 95                       25.0                        20.5           -18.74
#
# [96 rows x 28 columns]

# %% [markdown]
# 3. Make up 1 interesting question about this dataset. Answer it

# %% [markdown]
# ## World Population Data

# %%
iq = pd.read_csv("iq.csv")

# %%
life_expec = pd.read_csv("life_expectancy.csv")

# %%
quality_of_life = pd.read_csv("quality_of_life.csv")

# %%
pop_density = pd.read_csv("population_density.csv")

# %%
height_weight = pd.read_csv("height_weight_data.csv")

# %% [markdown]
# 4. Join the height and weight data to the iq data.

# %%
df_cd = pd.merge(height_weight, iq, how='outer')
df_cd
# Out:
#                     country  male_height  female_height  male_weight  \
# 0               Netherlands        184.0          170.0         87.9
# 1                Montenegro        183.0          170.0         90.4
# 2                   Estonia        182.0          168.0         89.9
# 3                   Denmark        182.0          169.0         86.8
# 4    Bosnia and Herzegovina        182.0          167.0         87.1
# ..                      ...          ...            ...          ...
# 135           Guinea-Bissau          NaN            NaN          NaN
# 136                 Senegal          NaN            NaN          NaN
# 137                  Gambia          NaN            NaN          NaN
# 138                   Gabon          NaN            NaN          NaN
# 139   Sao Tome and Principe          NaN            NaN          NaN
#
#      female_weight  male_bmi  female_bmi     iq  \
# 0             73.2      26.1        25.3  102.0
# 1             75.3      27.0        26.2   84.0
# 2             73.7      27.0        26.0   99.0
# 3             70.2      26.3        24.6   99.0
# 4             70.6      26.4        25.3    NaN
# ..             ...       ...         ...    ...
# 135            NaN       NaN         NaN   62.0
# 136            NaN       NaN         NaN   60.0
# 137            NaN       NaN         NaN   60.0
# 138            NaN       NaN         NaN   60.0
# 139            NaN       NaN         NaN   58.0
#
#     education_expenditure_per_inhabitant  daily_max_temp
# 0                                  1,701            14.4
# 1                                    NaN            21.0
# 2                                    459            10.1
# 3                                  3,127            12.5
# 4                                    NaN             NaN
# ..                                   ...             ...
# 135                                   13            33.4
# 136                                   37            35.3
# 137                                   13            32.9
# 138                                  192            29.8
# 139                                   55            28.6
#
# [140 rows x 10 columns]

# %% [markdown]
# 5. Join population density to quiality of life data.

# %%
df_cd = pd.merge(pop_density, quality_of_life, how='outer')
df_cd
# Out:
#                    country    area population  pop_per_km_sq  stability  \
# 0                   Macao     30.0     0.66 M        21657.6        NaN
# 1                   Monaco     2.0     0.04 M        19564.4        NaN
# 2                Singapore   719.0     5.45 M         7584.9       83.0
# 3               Hong Kong   1110.0     7.41 M         6678.5        NaN
# 4               Gibraltar      6.8     0.03 M         4954.6        NaN
# ..                     ...     ...        ...            ...        ...
# 162             Mozambique     NaN        NaN            NaN       36.0
# 163                   Iraq     NaN        NaN            NaN       16.0
# 164                   Chad     NaN        NaN            NaN       46.0
# 165                  Sudan     NaN        NaN            NaN        8.0
# 166  Congo (Dem. Republic)     NaN        NaN            NaN       32.0
#
#      rights  health  safety  climate  costs  popularity
# 0       NaN     NaN     NaN      NaN    NaN         NaN
# 1       NaN     NaN     NaN      NaN    NaN         NaN
# 2      89.0    79.0   100.0     45.0   55.0        42.0
# 3       NaN     NaN     NaN      NaN    NaN         NaN
# 4       NaN     NaN     NaN      NaN    NaN         NaN
# ..      ...     ...     ...      ...    ...         ...
# 162    26.0    10.0     4.0     81.0   53.0        35.0
# 163    12.0    42.0    29.0     37.0   75.0        33.0
# 164    12.0     0.0    31.0     50.0   49.0        44.0
# 165    11.0    18.0    55.0     40.0   66.0        24.0
# 166     7.0     6.0    10.0     54.0   60.0        36.0
#
# [167 rows x 11 columns]

# %% [markdown]
# 6. Join life expectancy to quality of life data

# %% [markdown]
# 7. Join iq, life expectancy, quality of life and population density into 1 dataframe.

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\shelt\OneDrive\Documents\GitHub\cis277-fa22-Lab4\Lab4.ipynb Cell 28 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/shelt/OneDrive/Documents/GitHub/cis277-fa22-Lab4/Lab4.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> df_cd = pd.merge(life_expec,quality_of_life,pop_density, how='outer')
#       <a href='vscode-notebook-cell:/c%3A/Users/shelt/OneDrive/Documents/GitHub/cis277-fa22-Lab4/Lab4.ipynb#X44sZmlsZQ%3D%3D?line=1'>2</a> df_cd
#
# TypeError: merge() got multiple values for argument 'how'

# %% [markdown]
# 8. Make up 1 interesting question about this dataset and answer it

# %% [markdown]
# 9. Make up 1 interesting question about this dataset and answer it

# %% [markdown]
# 10. Make up 1 interesting question about this dataset and answer it
